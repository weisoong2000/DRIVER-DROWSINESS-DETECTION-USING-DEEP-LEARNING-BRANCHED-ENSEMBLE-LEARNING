# %%
from keras.layers import Input, Lambda, Dense, Flatten, Conv2D, MaxPooling2D, BatchNormalization, Dropout
from keras.models import Model
from keras.applications.vgg16 import VGG16
from keras.applications.vgg16 import preprocess_input
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
import numpy as np
from glob import glob
import matplotlib.pyplot as plt
import tensorflow as tf
import random

# %%
random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)

# %%
import keras.backend as K

def categorical_focal_loss(alpha, gamma=2.):

    alpha = np.array(alpha, dtype=np.float32)

    def categorical_focal_loss_fixed(y_true, y_pred):
        """
        :param y_true: A tensor of the same shape as `y_pred`
        :param y_pred: A tensor resulting from a softmax
        :return: Output tensor.
        """

        # Clip the prediction value to prevent NaN's and Inf's
        epsilon = K.epsilon()
        y_pred = K.clip(y_pred, epsilon, 1. - epsilon)

        # Calculate Cross Entropy
        cross_entropy = -y_true * K.log(y_pred)

        # Calculate Focal Loss
        loss = alpha * K.pow(1 - y_pred, gamma) * cross_entropy

        # Compute mean loss in mini_batch
        return K.mean(K.sum(loss, axis=-1))

    return categorical_focal_loss_fixed

# %%
# useful for getting number of classes
folders = glob('C:/CKplus/data/train/*')
print("Number of folders,\n",folders)
# Out:
# Number of folders,
#  ['C:/Users/wweis/Deep Learning/CKplus/data/train\\anger', 'C:/Users/wweis/Deep Learning/CKplus/data/train\\contempt', 'C:/Users/wweis/Deep Learning/CKplus/data/train\\disgust', 'C:/Users/wweis/Deep Learning/CKplus/data/train\\fear', 'C:/Users/wweis/Deep Learning/CKplus/data/train\\happy', 'C:/Users/wweis/Deep Learning/CKplus/data/train\\sadness', 'C:/Users/wweis/Deep Learning/CKplus/data/train\\surprise']

# %% [markdown]
# ## Data Augmentation

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

training_set = train_datagen.flow_from_directory('C:/CKplus/data/train',
                                                 target_size = (224, 224),
                                                 batch_size = 32,
                                                 class_mode = 'categorical',
                                                 shuffle=True,
                                                 seed=42)

validation_set = test_datagen.flow_from_directory(
        'C:/CKplus/data/valid',
        target_size=(224, 224),
        batch_size=32,
        class_mode='categorical',
        shuffle=True,
        seed=42)

test_set = test_datagen.flow_from_directory('C:/CKplus/data/test',
                                            target_size = (224, 224),
                                            batch_size=1,
                                            class_mode='categorical',
                                            shuffle=False,
                                            seed=42)
# Out:
# Found 686 images belonging to 7 classes.
# Found 98 images belonging to 7 classes.
# Found 197 images belonging to 7 classes.

# %%
print(len(training_set))
print(len(training_set.classes))
# Out:
# 22
# 686

# %% [markdown]
# ## Pretrained VGG-16

# %%
# add preprocessing layer to the front of VGG
vgg = VGG16(input_shape=(224, 224, 3), weights='imagenet', include_top=False)

# don't train existing weights
for layer in vgg.layers:
  layer.trainable = False

# %%
x = vgg.get_layer('block1_pool').output
coarse_1 = Flatten()(x)
coarse_1 = Dense(64, activation='relu')(coarse_1)
coarse_1 = BatchNormalization()(coarse_1)
coarse_1 = Dropout(0.2)(coarse_1)
c_1_pred = Dense(len(folders), activation='softmax', name='branch_1')(coarse_1)

x = vgg.get_layer('block2_pool').output
coarse_2 = Flatten()(x)
coarse_2 = Dense(64, activation='relu')(coarse_2)
coarse_2 = BatchNormalization()(coarse_2)
coarse_2 = Dropout(0.2)(coarse_2)
c_2_pred = Dense(len(folders), activation='softmax', name='branch_2')(coarse_2)

x = vgg.get_layer('block3_pool').output
coarse_3 = Flatten()(x)
coarse_3 = Dense(64, activation='relu')(coarse_3)
coarse_3 = BatchNormalization()(coarse_3)
coarse_3 = Dropout(0.2)(coarse_3)
c_3_pred = Dense(len(folders), activation='softmax', name='branch_3')(coarse_3)

x = vgg.get_layer('block4_pool').output
coarse_4 = Flatten()(x)
coarse_4 = Dense(64, activation='relu')(coarse_4)
coarse_4 = BatchNormalization()(coarse_4)
coarse_4 = Dropout(0.2)(coarse_4)
c_4_pred = Dense(len(folders), activation='softmax', name='branch_4')(coarse_4)

x = vgg.get_layer('block5_pool').output
fine = Flatten()(x)
fine = Dense(64, activation='relu')(fine)
fine = BatchNormalization()(fine)
fine = Dropout(0.2)(fine)
fine_pred = Dense(len(folders), activation='softmax', name='fine_branch')(fine)

# create a model object
model = Model(inputs=vgg.input, outputs=[c_1_pred, c_2_pred, c_3_pred, c_4_pred, fine_pred])

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 224, 224, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 224, 224, 64) 36928       block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 112, 112, 64) 0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, 112, 112, 128 73856       block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv2D)           (None, 112, 112, 128 147584      block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 56, 56, 128)  0           block2_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv2D)           (None, 56, 56, 256)  295168      block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv2D)           (None, 56, 56, 256)  590080      block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv3 (Conv2D)           (None, 56, 56, 256)  590080      block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 28, 28, 256)  0           block3_conv3[0][0]
# __________________________________________________________________________________________________
# block4_conv1 (Conv2D)           (None, 28, 28, 512)  1180160     block3_pool[0][0]
# __________________________________________________________________________________________________
# block4_conv2 (Conv2D)           (None, 28, 28, 512)  2359808     block4_conv1[0][0]
# __________________________________________________________________________________________________
# block4_conv3 (Conv2D)           (None, 28, 28, 512)  2359808     block4_conv2[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 14, 14, 512)  0           block4_conv3[0][0]
# __________________________________________________________________________________________________
# block5_conv1 (Conv2D)           (None, 14, 14, 512)  2359808     block4_pool[0][0]
# __________________________________________________________________________________________________
# block5_conv2 (Conv2D)           (None, 14, 14, 512)  2359808     block5_conv1[0][0]
# __________________________________________________________________________________________________
# block5_conv3 (Conv2D)           (None, 14, 14, 512)  2359808     block5_conv2[0][0]
# __________________________________________________________________________________________________
# block5_pool (MaxPooling2D)      (None, 7, 7, 512)    0           block5_conv3[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 802816)       0           block1_pool[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 401408)       0           block2_pool[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 200704)       0           block3_pool[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 100352)       0           block4_pool[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 25088)        0           block5_pool[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 64)           51380288    flatten[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           25690176    flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           12845120    flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 64)           6422592     flatten_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 64)           1605696     flatten_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 64)           256         dense[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 64)           256         dense_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64)           256         dense_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64)           256         dense_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64)           256         dense_4[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 64)           0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64)           0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 64)           0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 64)           0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 64)           0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# branch_1 (Dense)                (None, 7)            455         dropout[0][0]
# __________________________________________________________________________________________________
# branch_2 (Dense)                (None, 7)            455         dropout_1[0][0]
# __________________________________________________________________________________________________
# branch_3 (Dense)                (None, 7)            455         dropout_2[0][0]
# __________________________________________________________________________________________________
# branch_4 (Dense)                (None, 7)            455         dropout_3[0][0]
# __________________________________________________________________________________________________
# fine_branch (Dense)             (None, 7)            455         dropout_4[0][0]
# ==================================================================================================
# Total params: 112,662,115
# Trainable params: 97,946,787
# Non-trainable params: 14,715,328
# __________________________________________________________________________________________________

# %%
model.compile(
  loss='categorical_crossentropy',
#   loss=categorical_focal_loss(alpha=0.25, gamma=2),
  optimizer='adam',
  metrics=['accuracy']
)

# %% [markdown]
# ## Train the Model

# %%
hist = model.fit(
          training_set,
          validation_data=validation_set,
          epochs=20,
          steps_per_epoch=len(training_set),
          validation_steps=len(validation_set),
          verbose=1
)
# Out:
# Epoch 1/20
# 22/22 [==============================] - 27s 733ms/step - loss: 7.3349 - branch_1_loss: 2.2023 - branch_2_loss: 1.5826 - branch_3_loss: 1.3412 - branch_4_loss: 1.1476 - fine_branch_loss: 1.0611 - branch_1_accuracy: 0.1851 - branch_2_accuracy: 0.4446 - branch_3_accuracy: 0.5219 - branch_4_accuracy: 0.5991 - fine_branch_accuracy: 0.6385 - val_loss: 138.6827 - val_branch_1_loss: 56.6220 - val_branch_2_loss: 46.9870 - val_branch_3_loss: 21.3862 - val_branch_4_loss: 11.3928 - val_fine_branch_loss: 2.2947 - val_branch_1_accuracy: 0.1939 - val_branch_2_accuracy: 0.1327 - val_branch_3_accuracy: 0.1122 - val_branch_4_accuracy: 0.2347 - val_fine_branch_accuracy: 0.5612
# Epoch 2/20
# 22/22 [==============================] - 10s 438ms/step - loss: 4.9095 - branch_1_loss: 1.8578 - branch_2_loss: 1.0556 - branch_3_loss: 0.8214 - branch_4_loss: 0.6294 - fine_branch_loss: 0.5454 - branch_1_accuracy: 0.3090 - branch_2_accuracy: 0.6866 - branch_3_accuracy: 0.7362 - branch_4_accuracy: 0.8294 - fine_branch_accuracy: 0.8367 - val_loss: 86.5391 - val_branch_1_loss: 48.4582 - val_branch_2_loss: 22.7660 - val_branch_3_loss: 9.3393 - val_branch_4_loss: 4.4316 - val_fine_branch_loss: 1.5440 - val_branch_1_accuracy: 0.1939 - val_branch_2_accuracy: 0.1327 - val_branch_3_accuracy: 0.2653 - val_branch_4_accuracy: 0.4388 - val_fine_branch_accuracy: 0.6224
# Epoch 3/20
# 22/22 [==============================] - 10s 441ms/step - loss: 4.0417 - branch_1_loss: 1.7087 - branch_2_loss: 0.8572 - branch_3_loss: 0.6408 - branch_4_loss: 0.4617 - fine_branch_loss: 0.3733 - branch_1_accuracy: 0.3965 - branch_2_accuracy: 0.7566 - branch_3_accuracy: 0.8207 - branch_4_accuracy: 0.9140 - fine_branch_accuracy: 0.9184 - val_loss: 40.6648 - val_branch_1_loss: 18.8056 - val_branch_2_loss: 13.6889 - val_branch_3_loss: 4.5606 - val_branch_4_loss: 2.6777 - val_fine_branch_loss: 0.9320 - val_branch_1_accuracy: 0.1939 - val_branch_2_accuracy: 0.1327 - val_branch_3_accuracy: 0.3571 - val_branch_4_accuracy: 0.5306 - val_fine_branch_accuracy: 0.6327
# Epoch 4/20
# 22/22 [==============================] - 10s 444ms/step - loss: 3.3129 - branch_1_loss: 1.5175 - branch_2_loss: 0.7040 - branch_3_loss: 0.4886 - branch_4_loss: 0.3329 - fine_branch_loss: 0.2699 - branch_1_accuracy: 0.4913 - branch_2_accuracy: 0.8076 - branch_3_accuracy: 0.8746 - branch_4_accuracy: 0.9490 - fine_branch_accuracy: 0.9490 - val_loss: 26.0052 - val_branch_1_loss: 11.8885 - val_branch_2_loss: 8.7394 - val_branch_3_loss: 2.4664 - val_branch_4_loss: 1.9449 - val_fine_branch_loss: 0.9660 - val_branch_1_accuracy: 0.1939 - val_branch_2_accuracy: 0.1327 - val_branch_3_accuracy: 0.4184 - val_branch_4_accuracy: 0.5612 - val_fine_branch_accuracy: 0.6429
# Epoch 5/20
# 22/22 [==============================] - 10s 438ms/step - loss: 2.8431 - branch_1_loss: 1.3633 - branch_2_loss: 0.6215 - branch_3_loss: 0.3945 - branch_4_loss: 0.2460 - fine_branch_loss: 0.2178 - branch_1_accuracy: 0.5758 - branch_2_accuracy: 0.8440 - branch_3_accuracy: 0.9155 - branch_4_accuracy: 0.9738 - fine_branch_accuracy: 0.9621 - val_loss: 19.3755 - val_branch_1_loss: 8.8430 - val_branch_2_loss: 6.8452 - val_branch_3_loss: 1.3910 - val_branch_4_loss: 1.4830 - val_fine_branch_loss: 0.8134 - val_branch_1_accuracy: 0.1939 - val_branch_2_accuracy: 0.1327 - val_branch_3_accuracy: 0.5000 - val_branch_4_accuracy: 0.5918 - val_fine_branch_accuracy: 0.6837
# Epoch 6/20
# 22/22 [==============================] - 10s 446ms/step - loss: 2.4494 - branch_1_loss: 1.2910 - branch_2_loss: 0.4995 - branch_3_loss: 0.3030 - branch_4_loss: 0.1787 - fine_branch_loss: 0.1772 - branch_1_accuracy: 0.5933 - branch_2_accuracy: 0.8761 - branch_3_accuracy: 0.9431 - branch_4_accuracy: 0.9854 - fine_branch_accuracy: 0.9606 - val_loss: 12.5761 - val_branch_1_loss: 5.9966 - val_branch_2_loss: 4.4391 - val_branch_3_loss: 0.8112 - val_branch_4_loss: 0.8546 - val_fine_branch_loss: 0.4747 - val_branch_1_accuracy: 0.1939 - val_branch_2_accuracy: 0.1327 - val_branch_3_accuracy: 0.6327 - val_branch_4_accuracy: 0.6735 - val_fine_branch_accuracy: 0.8163
# Epoch 7/20
# 22/22 [==============================] - 10s 447ms/step - loss: 2.2764 - branch_1_loss: 1.2130 - branch_2_loss: 0.4707 - branch_3_loss: 0.2667 - branch_4_loss: 0.1632 - fine_branch_loss: 0.1628 - branch_1_accuracy: 0.6122 - branch_2_accuracy: 0.8907 - branch_3_accuracy: 0.9475 - branch_4_accuracy: 0.9810 - fine_branch_accuracy: 0.9679 - val_loss: 9.5819 - val_branch_1_loss: 4.3838 - val_branch_2_loss: 3.6654 - val_branch_3_loss: 0.5928 - val_branch_4_loss: 0.4763 - val_fine_branch_loss: 0.4636 - val_branch_1_accuracy: 0.2347 - val_branch_2_accuracy: 0.1429 - val_branch_3_accuracy: 0.7245 - val_branch_4_accuracy: 0.8265 - val_fine_branch_accuracy: 0.8673
# Epoch 8/20
# 22/22 [==============================] - 10s 447ms/step - loss: 1.9287 - branch_1_loss: 1.0728 - branch_2_loss: 0.3958 - branch_3_loss: 0.2169 - branch_4_loss: 0.1227 - fine_branch_loss: 0.1205 - branch_1_accuracy: 0.6647 - branch_2_accuracy: 0.9242 - branch_3_accuracy: 0.9665 - branch_4_accuracy: 0.9898 - fine_branch_accuracy: 0.9825 - val_loss: 6.6248 - val_branch_1_loss: 3.6153 - val_branch_2_loss: 2.0181 - val_branch_3_loss: 0.3756 - val_branch_4_loss: 0.3184 - val_fine_branch_loss: 0.2974 - val_branch_1_accuracy: 0.2449 - val_branch_2_accuracy: 0.3878 - val_branch_3_accuracy: 0.8163 - val_branch_4_accuracy: 0.8980 - val_fine_branch_accuracy: 0.9082
# Epoch 9/20
# 22/22 [==============================] - 10s 460ms/step - loss: 1.7604 - branch_1_loss: 1.0052 - branch_2_loss: 0.3651 - branch_3_loss: 0.1877 - branch_4_loss: 0.1027 - fine_branch_loss: 0.0996 - branch_1_accuracy: 0.6866 - branch_2_accuracy: 0.9242 - branch_3_accuracy: 0.9665 - branch_4_accuracy: 0.9913 - fine_branch_accuracy: 0.9869 - val_loss: 5.1835 - val_branch_1_loss: 2.5262 - val_branch_2_loss: 1.7960 - val_branch_3_loss: 0.2605 - val_branch_4_loss: 0.3206 - val_fine_branch_loss: 0.2802 - val_branch_1_accuracy: 0.4694 - val_branch_2_accuracy: 0.4082 - val_branch_3_accuracy: 0.8878 - val_branch_4_accuracy: 0.8673 - val_fine_branch_accuracy: 0.9184
# Epoch 10/20
# 22/22 [==============================] - 10s 449ms/step - loss: 1.5641 - branch_1_loss: 0.9035 - branch_2_loss: 0.3097 - branch_3_loss: 0.1557 - branch_4_loss: 0.0958 - fine_branch_loss: 0.0995 - branch_1_accuracy: 0.7347 - branch_2_accuracy: 0.9315 - branch_3_accuracy: 0.9723 - branch_4_accuracy: 0.9854 - fine_branch_accuracy: 0.9825 - val_loss: 3.3496 - val_branch_1_loss: 2.0960 - val_branch_2_loss: 0.7189 - val_branch_3_loss: 0.1797 - val_branch_4_loss: 0.1669 - val_fine_branch_loss: 0.1880 - val_branch_1_accuracy: 0.5816 - val_branch_2_accuracy: 0.7347 - val_branch_3_accuracy: 0.9796 - val_branch_4_accuracy: 0.9490 - val_fine_branch_accuracy: 0.9388
# Epoch 11/20
# 22/22 [==============================] - 10s 451ms/step - loss: 1.3832 - branch_1_loss: 0.8353 - branch_2_loss: 0.2684 - branch_3_loss: 0.1278 - branch_4_loss: 0.0724 - fine_branch_loss: 0.0793 - branch_1_accuracy: 0.7478 - branch_2_accuracy: 0.9548 - branch_3_accuracy: 0.9796 - branch_4_accuracy: 0.9942 - fine_branch_accuracy: 0.9898 - val_loss: 2.6541 - val_branch_1_loss: 1.6107 - val_branch_2_loss: 0.6493 - val_branch_3_loss: 0.1436 - val_branch_4_loss: 0.1030 - val_fine_branch_loss: 0.1475 - val_branch_1_accuracy: 0.6939 - val_branch_2_accuracy: 0.7653 - val_branch_3_accuracy: 0.9898 - val_branch_4_accuracy: 0.9592 - val_fine_branch_accuracy: 0.9592
# Epoch 12/20
# 22/22 [==============================] - 10s 443ms/step - loss: 1.3320 - branch_1_loss: 0.7881 - branch_2_loss: 0.2699 - branch_3_loss: 0.1205 - branch_4_loss: 0.0736 - fine_branch_loss: 0.0799 - branch_1_accuracy: 0.7551 - branch_2_accuracy: 0.9519 - branch_3_accuracy: 0.9796 - branch_4_accuracy: 0.9927 - fine_branch_accuracy: 0.9883 - val_loss: 2.7718 - val_branch_1_loss: 1.5962 - val_branch_2_loss: 0.8941 - val_branch_3_loss: 0.1097 - val_branch_4_loss: 0.0750 - val_fine_branch_loss: 0.0968 - val_branch_1_accuracy: 0.6224 - val_branch_2_accuracy: 0.7143 - val_branch_3_accuracy: 0.9898 - val_branch_4_accuracy: 0.9796 - val_fine_branch_accuracy: 0.9898
# Epoch 13/20
# 22/22 [==============================] - 10s 449ms/step - loss: 1.1721 - branch_1_loss: 0.6925 - branch_2_loss: 0.2425 - branch_3_loss: 0.1039 - branch_4_loss: 0.0595 - fine_branch_loss: 0.0737 - branch_1_accuracy: 0.7915 - branch_2_accuracy: 0.9636 - branch_3_accuracy: 0.9898 - branch_4_accuracy: 0.9985 - fine_branch_accuracy: 0.9883 - val_loss: 2.2548 - val_branch_1_loss: 1.3606 - val_branch_2_loss: 0.6415 - val_branch_3_loss: 0.0995 - val_branch_4_loss: 0.0448 - val_fine_branch_loss: 0.1085 - val_branch_1_accuracy: 0.4898 - val_branch_2_accuracy: 0.7857 - val_branch_3_accuracy: 0.9898 - val_branch_4_accuracy: 1.0000 - val_fine_branch_accuracy: 0.9898
# Epoch 14/20
# 22/22 [==============================] - 10s 451ms/step - loss: 1.0890 - branch_1_loss: 0.6664 - branch_2_loss: 0.2147 - branch_3_loss: 0.0913 - branch_4_loss: 0.0525 - fine_branch_loss: 0.0641 - branch_1_accuracy: 0.8032 - branch_2_accuracy: 0.9563 - branch_3_accuracy: 0.9898 - branch_4_accuracy: 0.9942 - fine_branch_accuracy: 0.9898 - val_loss: 2.2106 - val_branch_1_loss: 1.5157 - val_branch_2_loss: 0.4614 - val_branch_3_loss: 0.0797 - val_branch_4_loss: 0.0526 - val_fine_branch_loss: 0.1012 - val_branch_1_accuracy: 0.4796 - val_branch_2_accuracy: 0.8367 - val_branch_3_accuracy: 0.9898 - val_branch_4_accuracy: 1.0000 - val_fine_branch_accuracy: 0.9796
# Epoch 15/20
# 22/22 [==============================] - 10s 451ms/step - loss: 1.0027 - branch_1_loss: 0.5920 - branch_2_loss: 0.2085 - branch_3_loss: 0.0846 - branch_4_loss: 0.0586 - fine_branch_loss: 0.0589 - branch_1_accuracy: 0.8367 - branch_2_accuracy: 0.9534 - branch_3_accuracy: 0.9883 - branch_4_accuracy: 0.9913 - fine_branch_accuracy: 0.9942 - val_loss: 2.7690 - val_branch_1_loss: 2.3289 - val_branch_2_loss: 0.2452 - val_branch_3_loss: 0.0702 - val_branch_4_loss: 0.0455 - val_fine_branch_loss: 0.0790 - val_branch_1_accuracy: 0.2449 - val_branch_2_accuracy: 0.9286 - val_branch_3_accuracy: 0.9898 - val_branch_4_accuracy: 0.9898 - val_fine_branch_accuracy: 0.9694
# Epoch 16/20
# 22/22 [==============================] - 10s 452ms/step - loss: 0.8886 - branch_1_loss: 0.5553 - branch_2_loss: 0.1761 - branch_3_loss: 0.0623 - branch_4_loss: 0.0423 - fine_branch_loss: 0.0527 - branch_1_accuracy: 0.8411 - branch_2_accuracy: 0.9708 - branch_3_accuracy: 0.9927 - branch_4_accuracy: 0.9956 - fine_branch_accuracy: 0.9898 - val_loss: 1.6146 - val_branch_1_loss: 1.0979 - val_branch_2_loss: 0.3082 - val_branch_3_loss: 0.0647 - val_branch_4_loss: 0.0357 - val_fine_branch_loss: 0.1081 - val_branch_1_accuracy: 0.5306 - val_branch_2_accuracy: 0.8980 - val_branch_3_accuracy: 0.9898 - val_branch_4_accuracy: 1.0000 - val_fine_branch_accuracy: 0.9694
# Epoch 17/20
# 22/22 [==============================] - 10s 453ms/step - loss: 0.9056 - branch_1_loss: 0.5561 - branch_2_loss: 0.1943 - branch_3_loss: 0.0707 - branch_4_loss: 0.0404 - fine_branch_loss: 0.0442 - branch_1_accuracy: 0.8440 - branch_2_accuracy: 0.9519 - branch_3_accuracy: 0.9883 - branch_4_accuracy: 0.9971 - fine_branch_accuracy: 0.9956 - val_loss: 1.0785 - val_branch_1_loss: 0.7313 - val_branch_2_loss: 0.1803 - val_branch_3_loss: 0.0507 - val_branch_4_loss: 0.0362 - val_fine_branch_loss: 0.0800 - val_branch_1_accuracy: 0.7143 - val_branch_2_accuracy: 0.9388 - val_branch_3_accuracy: 0.9898 - val_branch_4_accuracy: 0.9898 - val_fine_branch_accuracy: 0.9694
# Epoch 18/20
# 22/22 [==============================] - 10s 446ms/step - loss: 0.8188 - branch_1_loss: 0.5276 - branch_2_loss: 0.1630 - branch_3_loss: 0.0524 - branch_4_loss: 0.0371 - fine_branch_loss: 0.0386 - branch_1_accuracy: 0.8455 - branch_2_accuracy: 0.9708 - branch_3_accuracy: 0.9956 - branch_4_accuracy: 0.9971 - fine_branch_accuracy: 0.9971 - val_loss: 2.1108 - val_branch_1_loss: 1.7831 - val_branch_2_loss: 0.1835 - val_branch_3_loss: 0.0527 - val_branch_4_loss: 0.0330 - val_fine_branch_loss: 0.0586 - val_branch_1_accuracy: 0.3469 - val_branch_2_accuracy: 0.9490 - val_branch_3_accuracy: 0.9898 - val_branch_4_accuracy: 0.9796 - val_fine_branch_accuracy: 0.9898
# Epoch 19/20
# 22/22 [==============================] - 10s 453ms/step - loss: 0.7562 - branch_1_loss: 0.4723 - branch_2_loss: 0.1460 - branch_3_loss: 0.0505 - branch_4_loss: 0.0285 - fine_branch_loss: 0.0590 - branch_1_accuracy: 0.8761 - branch_2_accuracy: 0.9767 - branch_3_accuracy: 0.9971 - branch_4_accuracy: 1.0000 - fine_branch_accuracy: 0.9883 - val_loss: 1.2483 - val_branch_1_loss: 0.8152 - val_branch_2_loss: 0.2290 - val_branch_3_loss: 0.0555 - val_branch_4_loss: 0.0426 - val_fine_branch_loss: 0.1060 - val_branch_1_accuracy: 0.6837 - val_branch_2_accuracy: 0.8980 - val_branch_3_accuracy: 0.9898 - val_branch_4_accuracy: 0.9796 - val_fine_branch_accuracy: 0.9796
# Epoch 20/20
# 22/22 [==============================] - 10s 452ms/step - loss: 0.7140 - branch_1_loss: 0.4542 - branch_2_loss: 0.1318 - branch_3_loss: 0.0538 - branch_4_loss: 0.0323 - fine_branch_loss: 0.0419 - branch_1_accuracy: 0.8746 - branch_2_accuracy: 0.9738 - branch_3_accuracy: 0.9898 - branch_4_accuracy: 0.9971 - fine_branch_accuracy: 0.9927 - val_loss: 1.1919 - val_branch_1_loss: 0.8377 - val_branch_2_loss: 0.1750 - val_branch_3_loss: 0.0682 - val_branch_4_loss: 0.0416 - val_fine_branch_loss: 0.0694 - val_branch_1_accuracy: 0.6837 - val_branch_2_accuracy: 0.9592 - val_branch_3_accuracy: 0.9898 - val_branch_4_accuracy: 0.9898 - val_fine_branch_accuracy: 0.9796

# %% [markdown]
# ## Plot the loss and accuracy

# %%
# loss
plt.title('Training Loss')
plt.plot(hist.history['loss'], label='train loss')
plt.plot(hist.history['val_loss'], label='val loss')
plt.plot(hist.history['branch_1_loss'], label='branch_1')
plt.plot(hist.history['val_branch_1_loss'], label='val_branch_1')
plt.plot(hist.history['branch_2_loss'], label='branch_2')
plt.plot(hist.history['val_branch_2_loss'], label='val_branch_2')
plt.plot(hist.history['branch_3_loss'], label='branch_3')
plt.plot(hist.history['val_branch_3_loss'], label='val_branch_3')
plt.plot(hist.history['branch_4_loss'], label='branch_4')
plt.plot(hist.history['val_branch_4_loss'], label='val_branch_4')
plt.plot(hist.history['fine_branch_loss'], label='fine')
plt.plot(hist.history['val_fine_branch_loss'], label='val_fine')
plt.legend()
plt.show()

# %%
# for i in range(3,8):
#     plt.plot(hist.history['dense_'+str(i)+'_accuracy'], label='dense_'+str(i)+'_accuracy')
#     plt.plot(hist.history['val_dense_'+str(i)+'_accuracy'], label='val_dense_'+str(i)+'_accuracy')
# plt.legend()
# plt.show()

# accuracy
plt.title('Training Accuracy')
plt.plot(hist.history['branch_1_accuracy'], label='branch_1')
plt.plot(hist.history['val_branch_1_accuracy'], label='val_branch_1')
plt.plot(hist.history['branch_2_accuracy'], label='branch_2')
plt.plot(hist.history['val_branch_2_accuracy'], label='val_branch_2')
plt.plot(hist.history['branch_3_accuracy'], label='branch_3')
plt.plot(hist.history['val_branch_3_accuracy'], label='val_branch_3')
plt.plot(hist.history['branch_4_accuracy'], label='branch_4')
plt.plot(hist.history['val_branch_4_accuracy'], label='val_branch_4')
plt.plot(hist.history['fine_branch_accuracy'], label='fine')
plt.plot(hist.history['val_fine_branch_accuracy'], label='val_fine')
plt.legend()
plt.show()

# %% [markdown]
# ## Model Evaluation / Prediction (test_set)

# %%
score_test = model.evaluate(test_set)
# Out:
# 197/197 [==============================] - 5s 25ms/step - loss: 1.0833 - branch_1_loss: 0.8205 - branch_2_loss: 0.1450 - branch_3_loss: 0.0552 - branch_4_loss: 0.0329 - fine_branch_loss: 0.0298 - branch_1_accuracy: 0.7157 - branch_2_accuracy: 0.9746 - branch_3_accuracy: 0.9898 - branch_4_accuracy: 0.9949 - fine_branch_accuracy: 0.9949

# %%
STEP_SIZE_TEST=test_set.n//test_set.batch_size
test_set.reset()
pred=model.predict(test_set,
                   steps=STEP_SIZE_TEST,
                   verbose=1)

# Get the number of unique labels
num_labels = len(np.unique(test_set.classes))

predicted_class_indices=np.argmax(pred[0],axis=1)

# Define a list of label names
label_names = ['anger', 'contempt', 'disgust', 'fear', 'happy', 'sadness', 'surprise']

# Compute the accuracy for each label
label_accs = {}
for label in range(num_labels):
    idx = np.where(test_set.classes == label)[0]
    label_acc = np.mean(predicted_class_indices[idx] == test_set.classes[idx])
    label_accs[label_names[label]] = label_acc

# Print the accuracy for each label
for label, acc in label_accs.items():
    print(f"Accuracy for label {label}: {acc:.2f}")
print("\n")

# labels = (training_set.class_indices)
# labels = dict((v,k) for k,v in labels.items())
# predictions = [labels[k] for k in predicted_class_indices]

from sklearn.metrics import confusion_matrix
import seaborn as sns
import pandas as pd

plt.figure(figsize=(20, 5))

# Make predictions on the test set
# y_pred = model.predict(test_set)

# Get the true labels for the test set
y_true = test_set.classes

# Compute the confusion matrix
conf_mat = confusion_matrix(y_true, predicted_class_indices)

df_cm = pd.DataFrame(conf_mat, index=['anger', 'contempt', 'disgust', 'fear', 'happy', 'sadness', 'surprise'], 
                     columns=['anger', 'contempt', 'disgust', 'fear', 'happy', 'sadness', 'surprise'])
plt.subplot(121)
plt.title("Confusion matrix - Coarse branch 1\n")
sns.heatmap(df_cm, annot=True, fmt="d", cmap="YlGnBu")
plt.ylabel("Predicted")
plt.xlabel("Actual")

from sklearn.metrics import classification_report

# Assuming y_true and y_pred are the true and predicted labels
report = classification_report(y_true, predicted_class_indices)
print(report)
# Out:
# 197/197 [==============================] - 4s 20ms/step
# Accuracy for label anger: 0.85
# Accuracy for label contempt: 1.00
# Accuracy for label disgust: 0.78
# Accuracy for label fear: 0.53
# Accuracy for label happy: 0.93
# Accuracy for label sadness: 0.18
# Accuracy for label surprise: 0.60
#
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.85      0.69        27
#            1       0.23      1.00      0.38        11
#            2       1.00      0.78      0.88        36
#            3       0.73      0.53      0.62        15
#            4       1.00      0.93      0.96        41
#            5       1.00      0.18      0.30        17
#            6       1.00      0.60      0.75        50
#
#     accuracy                           0.72       197
#    macro avg       0.79      0.70      0.65       197
# weighted avg       0.88      0.72      0.74       197

# %%
predicted_class_indices=np.argmax(pred[1],axis=1)

# Define a list of label names
# label_names = ['Closed', 'no_yawn', 'Open', 'yawn']

# Compute the accuracy for each label
label_accs = {}
for label in range(num_labels):
    idx = np.where(test_set.classes == label)[0]
    label_acc = np.mean(predicted_class_indices[idx] == test_set.classes[idx])
    label_accs[label_names[label]] = label_acc

# Print the accuracy for each label
for label, acc in label_accs.items():
    print(f"Accuracy for label {label}: {acc:.2f}")
print("\n")

from sklearn.metrics import confusion_matrix
import seaborn as sns
import pandas as pd

plt.figure(figsize=(20, 5))

# Make predictions on the test set
# y_pred = model.predict(test_set)

# Get the true labels for the test set
y_true = test_set.classes

# Compute the confusion matrix
conf_mat = confusion_matrix(y_true, predicted_class_indices)

df_cm = pd.DataFrame(conf_mat, index=['anger', 'contempt', 'disgust', 'fear', 'happy', 'sadness', 'surprise'], 
                     columns=['anger', 'contempt', 'disgust', 'fear', 'happy', 'sadness', 'surprise'])
plt.subplot(121)
plt.title("Confusion matrix - Coarse branch 2\n")
sns.heatmap(df_cm, annot=True, fmt="d", cmap="YlGnBu")
plt.ylabel("Predicted")
plt.xlabel("Actual")

from sklearn.metrics import classification_report

# Assuming y_true and y_pred are the true and predicted labels
report = classification_report(y_true, predicted_class_indices)
print(report)
# Out:
# Accuracy for label anger: 1.00
# Accuracy for label contempt: 1.00
# Accuracy for label disgust: 1.00
# Accuracy for label fear: 0.93
# Accuracy for label happy: 0.95
# Accuracy for label sadness: 0.88
# Accuracy for label surprise: 1.00
#
#
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        27
#            1       0.73      1.00      0.85        11
#            2       1.00      1.00      1.00        36
#            3       1.00      0.93      0.97        15
#            4       1.00      0.95      0.97        41
#            5       1.00      0.88      0.94        17
#            6       1.00      1.00      1.00        50
#
#     accuracy                           0.97       197
#    macro avg       0.96      0.97      0.96       197
# weighted avg       0.98      0.97      0.98       197

# %%
predicted_class_indices=np.argmax(pred[2],axis=1)

# Define a list of label names
# label_names = ['Closed', 'no_yawn', 'Open', 'yawn']

# Compute the accuracy for each label
label_accs = {}
for label in range(num_labels):
    idx = np.where(test_set.classes == label)[0]
    label_acc = np.mean(predicted_class_indices[idx] == test_set.classes[idx])
    label_accs[label_names[label]] = label_acc

# Print the accuracy for each label
for label, acc in label_accs.items():
    print(f"Accuracy for label {label}: {acc:.2f}")
print("\n")

from sklearn.metrics import confusion_matrix
import seaborn as sns
import pandas as pd

plt.figure(figsize=(20, 5))

# Make predictions on the test set
# y_pred = model.predict(test_set)

# Get the true labels for the test set
y_true = test_set.classes

# Compute the confusion matrix
conf_mat = confusion_matrix(y_true, predicted_class_indices)

df_cm = pd.DataFrame(conf_mat, index=['anger', 'contempt', 'disgust', 'fear', 'happy', 'sadness', 'surprise'], 
                     columns=['anger', 'contempt', 'disgust', 'fear', 'happy', 'sadness', 'surprise'])
plt.subplot(121)
plt.title("Confusion matrix - Coarse branch 3\n")
sns.heatmap(df_cm, annot=True, fmt="d", cmap="YlGnBu")
plt.ylabel("Predicted")
plt.xlabel("Actual")

from sklearn.metrics import classification_report

# Assuming y_true and y_pred are the true and predicted labels
report = classification_report(y_true, predicted_class_indices)
print(report)
# Out:
# Accuracy for label anger: 0.93
# Accuracy for label contempt: 1.00
# Accuracy for label disgust: 1.00
# Accuracy for label fear: 1.00
# Accuracy for label happy: 1.00
# Accuracy for label sadness: 1.00
# Accuracy for label surprise: 1.00
#
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.93      0.96        27
#            1       1.00      1.00      1.00        11
#            2       1.00      1.00      1.00        36
#            3       1.00      1.00      1.00        15
#            4       1.00      1.00      1.00        41
#            5       0.89      1.00      0.94        17
#            6       1.00      1.00      1.00        50
#
#     accuracy                           0.99       197
#    macro avg       0.98      0.99      0.99       197
# weighted avg       0.99      0.99      0.99       197

# %%
predicted_class_indices=np.argmax(pred[3],axis=1)

# Define a list of label names
# label_names = ['Closed', 'no_yawn', 'Open', 'yawn']

# Compute the accuracy for each label
label_accs = {}
for label in range(num_labels):
    idx = np.where(test_set.classes == label)[0]
    label_acc = np.mean(predicted_class_indices[idx] == test_set.classes[idx])
    label_accs[label_names[label]] = label_acc

# Print the accuracy for each label
for label, acc in label_accs.items():
    print(f"Accuracy for label {label}: {acc:.2f}")
print("\n")

from sklearn.metrics import confusion_matrix
import seaborn as sns
import pandas as pd

plt.figure(figsize=(20, 5))

# Make predictions on the test set
# y_pred = model.predict(test_set)

# Get the true labels for the test set
y_true = test_set.classes

# Compute the confusion matrix
conf_mat = confusion_matrix(y_true, predicted_class_indices)

df_cm = pd.DataFrame(conf_mat, index=['anger', 'contempt', 'disgust', 'fear', 'happy', 'sadness', 'surprise'], 
                     columns=['anger', 'contempt', 'disgust', 'fear', 'happy', 'sadness', 'surprise'])
plt.subplot(121)
plt.title("Confusion matrix - Coarse branch 4\n")
sns.heatmap(df_cm, annot=True, fmt="d", cmap="YlGnBu")
plt.ylabel("Predicted")
plt.xlabel("Actual")

from sklearn.metrics import classification_report

# Assuming y_true and y_pred are the true and predicted labels
report = classification_report(y_true, predicted_class_indices)
print(report)
# Out:
# Accuracy for label anger: 1.00
# Accuracy for label contempt: 1.00
# Accuracy for label disgust: 1.00
# Accuracy for label fear: 1.00
# Accuracy for label happy: 1.00
# Accuracy for label sadness: 0.94
# Accuracy for label surprise: 1.00
#
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        27
#            1       0.92      1.00      0.96        11
#            2       1.00      1.00      1.00        36
#            3       1.00      1.00      1.00        15
#            4       1.00      1.00      1.00        41
#            5       1.00      0.94      0.97        17
#            6       1.00      1.00      1.00        50
#
#     accuracy                           0.99       197
#    macro avg       0.99      0.99      0.99       197
# weighted avg       1.00      0.99      0.99       197

# %%
predicted_class_indices=np.argmax(pred[4],axis=1)

# Define a list of label names
# label_names = ['Closed', 'no_yawn', 'Open', 'yawn']

# Compute the accuracy for each label
label_accs = {}
for label in range(num_labels):
    idx = np.where(test_set.classes == label)[0]
    label_acc = np.mean(predicted_class_indices[idx] == test_set.classes[idx])
    label_accs[label_names[label]] = label_acc

# Print the accuracy for each label
for label, acc in label_accs.items():
    print(f"Accuracy for label {label}: {acc:.2f}")
print("\n")

from sklearn.metrics import confusion_matrix
import seaborn as sns
import pandas as pd

plt.figure(figsize=(20, 5))

# Make predictions on the test set
# y_pred = model.predict(test_set)

# Get the true labels for the test set
y_true = test_set.classes

# Compute the confusion matrix
conf_mat = confusion_matrix(y_true, predicted_class_indices)

df_cm = pd.DataFrame(conf_mat, index=['anger', 'contempt', 'disgust', 'fear', 'happy', 'sadness', 'surprise'], 
                     columns=['anger', 'contempt', 'disgust', 'fear', 'happy', 'sadness', 'surprise'])
plt.subplot(121)
plt.title("Confusion matrix - Fine branch\n")
sns.heatmap(df_cm, annot=True, fmt="d", cmap="YlGnBu")
plt.ylabel("Predicted")
plt.xlabel("Actual")

from sklearn.metrics import classification_report

# Assuming y_true and y_pred are the true and predicted labels
report = classification_report(y_true, predicted_class_indices)
print(report)
# Out:
# Accuracy for label anger: 1.00
# Accuracy for label contempt: 1.00
# Accuracy for label disgust: 1.00
# Accuracy for label fear: 1.00
# Accuracy for label happy: 1.00
# Accuracy for label sadness: 0.94
# Accuracy for label surprise: 1.00
#
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        27
#            1       1.00      1.00      1.00        11
#            2       1.00      1.00      1.00        36
#            3       0.94      1.00      0.97        15
#            4       1.00      1.00      1.00        41
#            5       1.00      0.94      0.97        17
#            6       1.00      1.00      1.00        50
#
#     accuracy                           0.99       197
#    macro avg       0.99      0.99      0.99       197
# weighted avg       1.00      0.99      0.99       197
